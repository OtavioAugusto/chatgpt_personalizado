# %% [markdown]
# <a href="https://colab.research.google.com/github/OtavioAugusto/chatgpt_personalizado/blob/main/meu_primeiro_chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Como criar um ChatGPT customizado usando modelos LLMs (ChatGPT)**

# %% [markdown]
# #### Instalar a bliblioteca da openai, caso não tenha instalada

# %%
# !pip install openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 1.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### Criar uma chave para uso da API em https://platform.openai.com/account/api-keys

# %%
import openai
openai.api_key = 'OpenAI_API_key' # Colocar a sua chave da OpenAI (OpenAI key)

# %% [markdown]
# ####  Função para obter resposta do modelo e retornar conteúdo com base nas mensagens de entrada

# %%
def get_completion_from_messages(messages, model="gpt-3.5-turbo", temperature=0):
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=temperature, #Este é o grau de aleatoriedade da saída do modelo
    )
    return response.choices[0].message["content"]

# %% [markdown]
# ### Criando uma interface para testar o bot

# %%
import panel as pn  # Interface
pn.extension()

panels = [] # Lista com as exibições
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='fc00cbe8-1480-46dc-92bd-ab6763c5dfc6'>
#   <div id="f955319d-0ea9-47eb-966a-8dbcc68bf679" data-root-id="fc00cbe8-1480-46dc-92bd-ab6763c5dfc6" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
def collect_messages(_):
    prompt = inp.value_input
    inp.value = ''
    context.append({'role':'user', 'content':f"{prompt}"})
    response = get_completion_from_messages(context)
    context.append({'role':'assistant', 'content':f"{response}"})
    panels.append(
        pn.Row('Usuário:', pn.pane.Markdown(prompt, width=600)))
    panels.append(
        pn.Row('Assistente:', pn.pane.Markdown(response, width=600, style={'background-color': '#F6F6F6'})))

    return pn.Column(*panels)

# %% [markdown]
# ### Ensinando ao Bot como ser um atendente de pedidos de sanduíches

# %%
context = [ {'role':'system', 'content':"""
Você é o SanduBot, um serviço automatizado para criação de pedidos para uma loja de sanduíches. \
Você primeiro deve cumprimentar o cliente, perguntar o nome dele e depois criar o pedido, \
depois você deve perguntar se o cliente irá buscar ou o pedido deverá ser uma entrega. \
Você espera para criar todo o pedido, depois deve resumi-lo e verificar o resultado final.
Aguarde, caso o cliente deseje adicionar mais alguma coisa. \
Se for uma entrega, você deve pedir um endereço. \
Para finalizar você recebe o pagamento.\
Certifique-se de esclarecer todas as opções e extras de forma exclusiva.
identifique o item no menu.\
Você responde em um estilo simples, curto e muito amigável, sem usar gírias ou regionalismos.\
O cardápio inclui \
sanduiche de presunto 9,00 \
sanduiche de cheedar 10,90 \
sanduiche de frango 11,95 \
batatas fritas 4,50 \
x-tudo 14,00 \
Adicionais: \
queijo extra 2,00, \
carne extra 1,50\
bacon 3,50 \
Molho especial IA 1,50 \
Bebidas: \
refrigerante 5,00 \
suco de laranja 3,00 \
água na garrafa 5,00 \
"""} ]  # Instruções ao bot

# %% [markdown]
# ### Ativar interface

# %%
inp = pn.widgets.TextInput(value="Olá", placeholder='Digite seu texto aqui…')
button_conversation = pn.widgets.Button(name="Chat!")
interactive_conversation = pn.bind(collect_messages, button_conversation)
dashboard = pn.Column(
    inp,
    pn.Row(button_conversation),
    pn.panel(interactive_conversation, loading_indicator=True, height=300),
)

dashboard
# Out:
# <ipython-input-14-7901d5b3ac0b>:10: PanelDeprecationWarning: 'style' is deprecated and will be removed in version 1.3, use 'styles' instead.
#   pn.Row('Assistente:', pn.pane.Markdown(response, width=600, style={'background-color': '#F6F6F6'})))
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# Column
#     [0] TextInput(placeholder='Digite seu texto aqui…')
#     [1] Row
#         [0] Button(name='Chat!')
#     [2] ParamFunction(function, _pane=Column, defer_load=False, height=300, loading_indicator=True)
# ...
